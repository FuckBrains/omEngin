# %%
import pandas as pd
import MySQLdb, os, pyodbc
from datetime import *
from dateutil.relativedelta import *
import numpy as np
from fn import *
import fluctuation as fl


def filter_p(df,reflst,oncolumn):
    i = 0
    dfx = pd.DataFrame([])
    rw = 0
    for k in reflst:
        i = i + 1
        ndf = df[df[oncolumn].str.contains(k)]
        rw = ndf.shape[0]
        if rw >= 2:
            if i == 1:
                dfx = ndf
            else:
                dfy = pd.concat([dfx,ndf])
                dfx = dfy
                dfy = pd.DataFrame([])
    else:
        return dfx

pt = os.getcwd() + "\\"
df = pd.read_csv(pt + 'SEMQRY.csv')
#print(df)
#df = semqry()
#df = df.astype (str)
#print(df.dtypes)
#xxx = main(df)
df = df.astype (str)
df1 = fl.catmap_mod(df)
df1.columns
df2 = filter_p(df1, ['2G', '3G', '4G'], 'CATX')
df3 = filter_p(df1, ['other'], 'CATX')
# Out:
# strart operation..............
# done duration

# %%
df2
# Out:
#            SERIAL            NODE  \
# 398     875289173           DBE50
# 399     875289229           DBE50
# 410     875294358           DBE50
# 411     875294359           DBE50
# 412     875294395           DBE50
# ...           ...             ...
# 155681  875293206         KGRJR01
# 155682  875293208         KGRJR01
# 155817  875221290  DH_VL01_vUSN03
# 155829  875227734  DH_VL01_vUSN03
# 155924  875307189        DHBNS59L
#
#                                               CUSTOMATTR3 EQUIPMENTKEY  \
# 398     RADIO X-CEIVER ADMINISTRATION MANAGED OBJECT F...   TNSDR57B01
# 399     RADIO X-CEIVER ADMINISTRATION MANAGED OBJECT F...   TNSDR57B01
# 410         CELL LOGICAL CHANNEL AVAILABILITY SUPERVISION      D50JJ7B
# 411         CELL LOGICAL CHANNEL AVAILABILITY SUPERVISION      D50JJ7G
# 412     RADIO X-CEIVER ADMINISTRATION MANAGED OBJECT F...   TNSDR57B01
# ...                                                   ...          ...
# 155681                                   CELL UNAVAILABLE  KGRJR01L09B
# 155682                                   CELL UNAVAILABLE  KGRJR01L18E
# 155817                                     S1AP LINK DOWN      SKDEB02
# 155829                                     S1AP LINK DOWN      SKDEB02
# 155924                                SERVICE UNAVAILABLE    DHBNS59LB
#
#        CUSTOMATTR15                            SUMMARY   LASTOCCURRENCE  \
# 398         TNSDR57                      ERI-OML FAULT  3/12/2020 16:55
# 399         TNSDR57                      ERI-OML FAULT  3/12/2020 16:55
# 410         TNSDR57  ERI-2G CELL DOWN_Cell Supervision  3/12/2020 17:02
# 411         TNSDR57  ERI-2G CELL DOWN_Cell Supervision  3/12/2020 17:02
# 412         TNSDR57                      ERI-OML FAULT  3/12/2020 17:02
# ...             ...                                ...              ...
# 155681      KGRJR01                   HUW-4G CELL DOWN  3/12/2020 16:59
# 155682      KGRJR01                   HUW-4G CELL DOWN  3/12/2020 16:59
# 155817      SKDEB02                   HUW-4G SITE DOWN  3/12/2020 10:53
# 155829      SKDEB02                   HUW-4G SITE DOWN  3/12/2020 11:04
# 155924      DHBNS59                   ERI-4G CELL DOWN  3/12/2020 17:42
#
#          CLEARTIMESTAMP CAT CATX   CODE   ZONE     DUR DURCAT          LO  \
# 398     3/12/2020 16:57   2   2G  TNSDR    MYM  327.55    H12  1203201655
# 399     3/12/2020 16:57   2   2G  TNSDR    MYM  327.55    H12  1203201655
# 410     3/12/2020 17:04  22   2G  TNSDR    MYM  320.55    H12  1203201702
# 411     3/12/2020 17:04  22   2G  TNSDR    MYM  320.55    H12  1203201702
# 412     3/12/2020 17:04   2   2G  TNSDR    MYM  320.55    H12  1203201702
# ...                 ...  ..  ...    ...    ...     ...    ...         ...
# 155681  3/12/2020 17:00  44   4G  KGRJR   RANG  323.58    H12  1203201659
# 155682  3/12/2020 17:00  44   4G  KGRJR   RANG  323.58    H12  1203201659
# 155817  3/12/2020 10:58   4   4G  SKDEB    KHL  689.58    H12  1203201053
# 155829  3/12/2020 11:24   4   4G  SKDEB    KHL  678.58    H12  1203201104
# 155924  3/12/2020 17:42  44   4G  DHBNS  DHK_M  280.58    H12  1203201742
#
#                      CDLO             CDLOTECH
# 398     TNSDR571203201655  TNSDR5712032016552G
# 399     TNSDR571203201655  TNSDR5712032016552G
# 410     TNSDR571203201702  TNSDR5712032017022G
# 411     TNSDR571203201702  TNSDR5712032017022G
# 412     TNSDR571203201702  TNSDR5712032017022G
# ...                   ...                  ...
# 155681  KGRJR011203201659  KGRJR0112032016594G
# 155682  KGRJR011203201659  KGRJR0112032016594G
# 155817  SKDEB021203201053  SKDEB0212032010534G
# 155829  SKDEB021203201104  SKDEB0212032011044G
# 155924  DHBNS591203201742  DHBNS5912032017424G
#
# [23341 rows x 17 columns]

# %%
df3
# Out:
#            SERIAL                                   NODE  \
# 0       875141043  9041-TNSDR60_OSN35_1(41-TN_DK1BO1_04)
# 1       875140017                                  DRE35
# 2       875140690                                  DRE35
# 3       875141544                                  DBE50
# 4       875141577  9041-TNSDR60_OSN35_1(41-TN_DK1BO1_04)
# ...           ...                                    ...
# 155926  875329974           9136-DHBNS60_OSN15_1(DH0063)
# 155927  875345633                               DHBNS59L
# 155928  875343790                                NWBLH01
# 155929  875343827                                NWBLH02
# 155930  874814739                                NWBLH02
#
#                                               CUSTOMATTR3  \
# 0                                                  B2_EXC
# 1       RADIO X-CEIVER ADMINISTRATION BTS EXTERNAL FAU...
# 2       RADIO X-CEIVER ADMINISTRATION BTS EXTERNAL FAU...
# 3       RADIO X-CEIVER ADMINISTRATION BTS EXTERNAL FAU...
# 4                                                   B2_SD
# ...                                                   ...
# 155926                                       VCAT_SQM_VC4
# 155927                                      LINK DEGRADED
# 155928                                   AC MAINS FAILURE
# 155929                                   AC MAINS FAILURE
# 155930                             RECTIFIER MODULE FAULT
#
#                                              EQUIPMENTKEY CUSTOMATTR15  \
# 0       9041-TNSDR60_OSN35_1(41-TN_DK1BO1_04)_source=9...      TNSDR60
# 1                                                 TNSDR73      TNSDR73
# 2                                              TNSDR31B02      TNSDR31
# 3                                                 TNSDR51      TNSDR51
# 4       9041-TNSDR60_OSN35_1(41-TN_DK1BO1_04)_source=9...      TNSDR60
# ...                                                   ...          ...
# 155926  9136-DHBNS60_OSN15_1(DH0063)_source=9136-DHBNS...      DHBNS60
# 155927                                           DHBNS59L      DHBNS59
# 155928                                            NWBLH01      NWBLH01
# 155929                                            NWBLH02      NWBLH02
# 155930                                            NWBLH02      NWBLH02
#
#                                                  SUMMARY   LASTOCCURRENCE  \
# 0                                             HUW-B2_EXC  2/12/2020 23:26
# 1                                          ERI-IVS FAULT  2/12/2020 23:29
# 2                                   ERI-AC MAINS FAILURE  2/12/2020 23:31
# 3                                   ERI-AC MAINS FAILURE  2/12/2020 23:31
# 4                                              HUW-B2_SD  2/12/2020 23:32
# ...                                                  ...              ...
# 155926  HUW-VC-4 VIRTUAL CONCATENATION SEQUENCE MISMATCH  3/12/2020 19:58
# 155927                                 ERI-LINK DEGRADED  3/12/2020 21:22
# 155928                                 HUW-MAINS FAILURE  3/12/2020 21:06
# 155929                                 HUW-MAINS FAILURE  3/12/2020 21:06
# 155930                               HUW-RECTIFIER FAULT  3/12/2020 21:09
#
#          CLEARTIMESTAMP    CAT   CATX   CODE   ZONE      DUR DURCAT  \
# 0       2/12/2020 23:32  other  other  TNSDR    MYM  1376.55    H24
# 1       2/12/2020 23:29  other  other  TNSDR    MYM  1373.55    H24
# 2        3/12/2020 0:36  other  other  TNSDR    MYM  1371.55    H24
# 3        3/12/2020 0:37  other  other  TNSDR    MYM  1371.55    H24
# 4       2/12/2020 23:32  other  other  TNSDR    MYM  1370.55    H24
# ...                 ...    ...    ...    ...    ...      ...    ...
# 155926    1/1/1970 6:00  other  other  DHBNS  DHK_M   144.58    H12
# 155927  3/12/2020 21:24  other  other  DHBNS  DHK_M    60.58     H2
# 155928  3/12/2020 21:09  other  other  NWBLH    RAJ    76.58     H2
# 155929  3/12/2020 21:09  other  other  NWBLH    RAJ    76.58     H2
# 155930    1/1/1970 6:00  other  other  NWBLH    RAJ    73.58     H2
#
#                 LO               CDLO                CDLOTECH
# 0       1202202326  TNSDR601202202326  TNSDR601202202326other
# 1       1202202329  TNSDR731202202329  TNSDR731202202329other
# 2       1202202331  TNSDR311202202331  TNSDR311202202331other
# 3       1202202331  TNSDR511202202331  TNSDR511202202331other
# 4       1202202332  TNSDR601202202332  TNSDR601202202332other
# ...            ...                ...                     ...
# 155926  1203201958  DHBNS601203201958  DHBNS601203201958other
# 155927  1203202122  DHBNS591203202122  DHBNS591203202122other
# 155928  1203202106  NWBLH011203202106  NWBLH011203202106other
# 155929  1203202106  NWBLH021203202106  NWBLH021203202106other
# 155930  1203202109  NWBLH021203202109  NWBLH021203202109other
#
# [132590 rows x 17 columns]

# %%
df4 = filter_p(df2, ['other'], 'CAT')

# %%
df4
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df2
# Out:
#            SERIAL            NODE  \
# 398     875289173           DBE50
# 399     875289229           DBE50
# 410     875294358           DBE50
# 411     875294359           DBE50
# 412     875294395           DBE50
# ...           ...             ...
# 155681  875293206         KGRJR01
# 155682  875293208         KGRJR01
# 155817  875221290  DH_VL01_vUSN03
# 155829  875227734  DH_VL01_vUSN03
# 155924  875307189        DHBNS59L
#
#                                               CUSTOMATTR3 EQUIPMENTKEY  \
# 398     RADIO X-CEIVER ADMINISTRATION MANAGED OBJECT F...   TNSDR57B01
# 399     RADIO X-CEIVER ADMINISTRATION MANAGED OBJECT F...   TNSDR57B01
# 410         CELL LOGICAL CHANNEL AVAILABILITY SUPERVISION      D50JJ7B
# 411         CELL LOGICAL CHANNEL AVAILABILITY SUPERVISION      D50JJ7G
# 412     RADIO X-CEIVER ADMINISTRATION MANAGED OBJECT F...   TNSDR57B01
# ...                                                   ...          ...
# 155681                                   CELL UNAVAILABLE  KGRJR01L09B
# 155682                                   CELL UNAVAILABLE  KGRJR01L18E
# 155817                                     S1AP LINK DOWN      SKDEB02
# 155829                                     S1AP LINK DOWN      SKDEB02
# 155924                                SERVICE UNAVAILABLE    DHBNS59LB
#
#        CUSTOMATTR15                            SUMMARY   LASTOCCURRENCE  \
# 398         TNSDR57                      ERI-OML FAULT  3/12/2020 16:55
# 399         TNSDR57                      ERI-OML FAULT  3/12/2020 16:55
# 410         TNSDR57  ERI-2G CELL DOWN_Cell Supervision  3/12/2020 17:02
# 411         TNSDR57  ERI-2G CELL DOWN_Cell Supervision  3/12/2020 17:02
# 412         TNSDR57                      ERI-OML FAULT  3/12/2020 17:02
# ...             ...                                ...              ...
# 155681      KGRJR01                   HUW-4G CELL DOWN  3/12/2020 16:59
# 155682      KGRJR01                   HUW-4G CELL DOWN  3/12/2020 16:59
# 155817      SKDEB02                   HUW-4G SITE DOWN  3/12/2020 10:53
# 155829      SKDEB02                   HUW-4G SITE DOWN  3/12/2020 11:04
# 155924      DHBNS59                   ERI-4G CELL DOWN  3/12/2020 17:42
#
#          CLEARTIMESTAMP CAT CATX   CODE   ZONE     DUR DURCAT          LO  \
# 398     3/12/2020 16:57   2   2G  TNSDR    MYM  327.55    H12  1203201655
# 399     3/12/2020 16:57   2   2G  TNSDR    MYM  327.55    H12  1203201655
# 410     3/12/2020 17:04  22   2G  TNSDR    MYM  320.55    H12  1203201702
# 411     3/12/2020 17:04  22   2G  TNSDR    MYM  320.55    H12  1203201702
# 412     3/12/2020 17:04   2   2G  TNSDR    MYM  320.55    H12  1203201702
# ...                 ...  ..  ...    ...    ...     ...    ...         ...
# 155681  3/12/2020 17:00  44   4G  KGRJR   RANG  323.58    H12  1203201659
# 155682  3/12/2020 17:00  44   4G  KGRJR   RANG  323.58    H12  1203201659
# 155817  3/12/2020 10:58   4   4G  SKDEB    KHL  689.58    H12  1203201053
# 155829  3/12/2020 11:24   4   4G  SKDEB    KHL  678.58    H12  1203201104
# 155924  3/12/2020 17:42  44   4G  DHBNS  DHK_M  280.58    H12  1203201742
#
#                      CDLO             CDLOTECH
# 398     TNSDR571203201655  TNSDR5712032016552G
# 399     TNSDR571203201655  TNSDR5712032016552G
# 410     TNSDR571203201702  TNSDR5712032017022G
# 411     TNSDR571203201702  TNSDR5712032017022G
# 412     TNSDR571203201702  TNSDR5712032017022G
# ...                   ...                  ...
# 155681  KGRJR011203201659  KGRJR0112032016594G
# 155682  KGRJR011203201659  KGRJR0112032016594G
# 155817  SKDEB021203201053  SKDEB0212032010534G
# 155829  SKDEB021203201104  SKDEB0212032011044G
# 155924  DHBNS591203201742  DHBNS5912032017424G
#
# [23341 rows x 17 columns]
