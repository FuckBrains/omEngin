# %%
import json
import requests
import os

def find_from_dict(key, dictionary):
    for k, v in dictionary.iteritems():
        if k == key:
            yield v
        elif isinstance(v, dict):
            for result in find(key, v):
                yield result
        elif isinstance(v, list):
            for d in v:
                for result in find(key, d):
                    yield result
    return result

def checkList(ele, prefix):
    for i in range(len(ele)):
        if (isinstance(ele[i], list)):
            checkList(ele[i], prefix+"["+str(i)+"]")
        elif (isinstance(ele[i], str)):
            printField(ele[i], prefix+"["+str(i)+"]")
        else:
            checkDict(ele[i], prefix+"["+str(i)+"]")

def checkDict(jsonObject, prefix):
    for ele in jsonObject:
        if (isinstance(jsonObject[ele], dict)):
            checkDict(jsonObject[ele], prefix+"."+ele)
        elif (isinstance(jsonObject[ele], list)):
            checkList(jsonObject[ele], prefix+"."+ele)
        elif (isinstance(jsonObject[ele], str)):
            printField(jsonObject[ele],  prefix+"."+ele)
            print('x')

def printField(ele, prefix):
    print (prefix, ":" , ele)


def get_all_values(nested_dictionary):
    for key, value in nested_dictionary.items():
        if type(value) is dict:
            get_all_values(value)
        else:
            print(key, ":", value)

def lp_dic(ddf1):
    for key in ddf1:
        print(key,ddf1[key])

def printall():
    pth = os.getcwd()
    print(pth)
    s1 = pth + '\\sample2.json'
    with open(s1, "r") as jsonFile:
            x = json.load(jsonFile)
            get_all_values(x)

def json_loop(data):
    for element in data: #If Json Field value is a Nested Json
        if (isinstance(data[element], dict)):
            checkDict(data[element], element)
        #If Json Field value is a list
        elif (isinstance(data[element], list)):
            checkList(data[element], element)
        #If Json Field value is a string
        elif (isinstance(data[element], str)):
            printField(data[element], element)
            
tele_sender = "https://api.telegram.org/bot1176189570:AAEfPi9TIZIbnhWi4Ko6KQev2Iv7UbMw5js/getupdates"
response = requests.get(tele_sender)
data = response.json()
#json_loop(data)

def prky(data):
    for key in data:
        print(key)
        #print(key, '->', data[key])

def Convert(lst):
    res_dct = {lst[i]: lst[i + 1] for i in range(0, len(lst), 2)}
    print(res_dct)        

nd1 = data['result']
d1 = dict.fromkeys(nd1[1] , 1)
d2 = { i : nd1[i] for i in range(0, len(nd1[1]) ) }
for i in range(len(nd1)):
    json_loop(nd1[i])
# Out:
# ~~dict~~
# message.from.first_name : Jalal
# message.from.last_name : Ahmad
# message.from.username : JalalAhmadRobi
# message.chat.title : RRU Theft 3hrs Plus
# message.chat.type : supergroup
# message.new_chat_participant.first_name : Ataur
# message.new_chat_participant.last_name : Rahman
# message.new_chat_participant.username : ataur_rahman
# message.new_chat_member.first_name : Ataur
# message.new_chat_member.last_name : Rahman
# message.new_chat_member.username : ataur_rahman
# message.new_chat_members[0].first_name : Ataur
# message.new_chat_members[0].last_name : Rahman
# message.new_chat_members[0].username : ataur_rahman
# ~~dict~~
# message.from.first_name : Jalal
# message.from.last_name : Ahmad
# message.from.username : JalalAhmadRobi
# message.chat.title : RRU Theft 3hrs Plus
# message.chat.type : supergroup
# message.new_chat_participant.first_name : Sohel
# message.new_chat_participant.last_name : Ahmed
# message.new_chat_participant.username : sohel_ahmed
# message.new_chat_member.first_name : Sohel
# message.new_chat_member.last_name : Ahmed
# message.new_chat_member.username : sohel_ahmed
# message.new_chat_members[0].first_name : Sohel
# message.new_chat_members[0].last_name : Ahmed
# message.new_chat_members[0].username : sohel_ahmed
# ~~dict~~
# message.from.first_name : Jalal
# message.from.last_name : Ahmad
# message.from.username : JalalAhmadRobi
# message.chat.title : RRU Theft 3hrs Plus
# message.chat.type : supergroup
# message.new_chat_participant.first_name : Abu
# message.new_chat_participant.last_name : Horayra
# message.new_chat_member.first_name : Abu
# message.new_chat_member.last_name : Horayra
# message.new_chat_members[0].first_name : Abu
# message.new_chat_members[0].last_name : Horayra
# ~~dict~~
# message.from.first_name : Jalal
# message.from.last_name : Ahmad
# message.from.username : JalalAhmadRobi
# message.chat.title : RRU Theft 3hrs Plus
# message.chat.type : supergroup
# message.new_chat_participant.first_name : Mahmudul
# message.new_chat_participant.last_name : Hasan
# message.new_chat_member.first_name : Mahmudul
# message.new_chat_member.last_name : Hasan
# message.new_chat_members[0].first_name : Mahmudul
# message.new_chat_members[0].last_name : Hasan
# ~~dict~~
# message.from.first_name : Jalal
# message.from.last_name : Ahmad
# message.from.username : JalalAhmadRobi
# message.chat.title : RRU Theft 3hrs Plus
# message.chat.type : supergroup
# message.new_chat_participant.first_name : Nazib
# message.new_chat_participant.last_name : Chowdhury
# message.new_chat_member.first_name : Nazib
# message.new_chat_member.last_name : Chowdhury
# message.new_chat_members[0].first_name : Nazib
# message.new_chat_members[0].last_name : Chowdhury
# ~~dict~~
# message.from.first_name : Jalal
# message.from.last_name : Ahmad
# message.from.username : JalalAhmadRobi
# message.chat.title : RRU Theft 3hrs Plus
# message.chat.type : supergroup
# message.new_chat_participant.first_name : Shihab
# message.new_chat_participant.last_name : Salim
# message.new_chat_participant.username : Shihabsalim
# message.new_chat_member.first_name : Shihab
# message.new_chat_member.last_name : Salim
# message.new_chat_member.username : Shihabsalim
# message.new_chat_members[0].first_name : Shihab
# message.new_chat_members[0].last_name : Salim
# message.new_chat_members[0].username : Shihabsalim
# ~~dict~~
# message.from.first_name : Jalal
# message.from.last_name : Ahmad
# message.from.username : JalalAhmadRobi
# message.chat.title : RRU Theft 3hrs Plus
# message.chat.type : supergroup
# message.left_chat_participant.first_name : Mahmudul
# message.left_chat_participant.last_name : Hasan
# message.left_chat_member.first_name : Mahmudul
# message.left_chat_member.last_name : Hasan
# ~~dict~~
# message.from.first_name : Mahmudul
# message.from.last_name : Babu
# message.from.username : BabuMPL
# message.chat.title : AT_Site_Down_PWR
# message.chat.type : group
# message.new_chat_participant.first_name : Md Mahabubul
# message.new_chat_participant.last_name : Islam
# message.new_chat_participant.username : ibappy
# message.new_chat_member.first_name : Md Mahabubul
# message.new_chat_member.last_name : Islam
# message.new_chat_member.username : ibappy
# message.new_chat_members[0].first_name : Md Mahabubul
# message.new_chat_members[0].last_name : Islam
# message.new_chat_members[0].username : ibappy
# ~~dict~~
# message.from.first_name : Mahmudul
# message.from.last_name : Babu
# message.from.username : BabuMPL
# message.chat.title : AT_Site_Down_PWR
# message.chat.type : group
# message.new_chat_participant.first_name : Mohidul
# message.new_chat_participant.last_name : Islam
# message.new_chat_member.first_name : Mohidul
# message.new_chat_member.last_name : Islam
# message.new_chat_members[0].first_name : Mohidul
# message.new_chat_members[0].last_name : Islam
# ~~dict~~
# message.from.first_name : Mahmudul
# message.from.last_name : Babu
# message.from.username : BabuMPL
# message.chat.title : AT_Site_Down_PWR
# message.chat.type : group
# message.new_chat_participant.first_name : Mofidul
# message.new_chat_participant.last_name : Islam
# message.new_chat_participant.username : Mofidul
# message.new_chat_member.first_name : Mofidul
# message.new_chat_member.last_name : Islam
# message.new_chat_member.username : Mofidul
# message.new_chat_members[0].first_name : Mofidul
# message.new_chat_members[0].last_name : Islam
# message.new_chat_members[0].username : Mofidul
# ~~dict~~
# message.from.first_name : Jalal
# message.from.last_name : Ahmad
# message.from.username : JalalAhmadRobi
# message.chat.title : RRU Theft 3hrs Plus
# message.chat.type : supergroup
# message.new_chat_participant.first_name : Mohammad Ziaul
# message.new_chat_participant.last_name : Hoque
# message.new_chat_member.first_name : Mohammad Ziaul
# message.new_chat_member.last_name : Hoque
# message.new_chat_members[0].first_name : Mohammad Ziaul
# message.new_chat_members[0].last_name : Hoque
# ~~dict~~
# message.from.first_name : Md.Nahiduzzaman
# message.from.username : Nahid_Metal
# message.chat.title : AT_Site_Down_PWR
# message.chat.type : group
# message.new_chat_participant.first_name : MD:ANAMUL
# message.new_chat_participant.last_name : HAQUE
# message.new_chat_participant.username : ULKA_FME_RAJ
# message.new_chat_member.first_name : MD:ANAMUL
# message.new_chat_member.last_name : HAQUE
# message.new_chat_member.username : ULKA_FME_RAJ
# message.new_chat_members[0].first_name : MD:ANAMUL
# message.new_chat_members[0].last_name : HAQUE
# message.new_chat_members[0].username : ULKA_FME_RAJ
# ~~dict~~
# message.from.first_name : Md.Nahiduzzaman
# message.from.username : Nahid_Metal
# message.chat.title : AT_Site_Down_PWR
# message.chat.type : group
# message.new_chat_participant.first_name : sadikur
# message.new_chat_participant.last_name : rahman
# message.new_chat_participant.username : Sadikur642
# message.new_chat_member.first_name : sadikur
# message.new_chat_member.last_name : rahman
# message.new_chat_member.username : Sadikur642
# message.new_chat_members[0].first_name : sadikur
# message.new_chat_members[0].last_name : rahman
# message.new_chat_members[0].username : Sadikur642
# ~~dict~~
# message.from.first_name : sadikur
# message.from.last_name : rahman
# message.from.username : Sadikur642
# message.chat.first_name : sadikur
# message.chat.last_name : rahman
# message.chat.username : Sadikur642
# message.chat.type : private
# message.text : /start
# message.entities[0].type : bot_command
# ~~dict~~
# message.from.first_name : sadikur
# message.from.last_name : rahman
# message.from.username : Sadikur642
# message.from.language_code : en
# message.chat.first_name : sadikur
# message.chat.last_name : rahman
# message.chat.username : Sadikur642
# message.chat.type : private
# message.text : //start
# ~~dict~~
# message.from.first_name : sadikur
# message.from.last_name : rahman
# message.from.username : Sadikur642
# message.from.language_code : en
# message.chat.first_name : sadikur
# message.chat.last_name : rahman
# message.chat.username : Sadikur642
# message.chat.type : private
# message.text : yes
# ~~dict~~
# message.from.first_name : Mustafiz
# message.from.last_name : Sohel
# message.from.username : MustafizS
# message.chat.title : RRU THEFT Detection
# message.chat.type : group
# message.text : KPI4G DHNMK13
# ~~dict~~
# message.from.first_name : Mustafiz
# message.from.last_name : Sohel
# message.from.username : MustafizS
# message.chat.title : RRU THEFT Detection
# message.chat.type : group
# message.text : KPI4G DHNMK06
# ~~dict~~
# message.from.first_name : Mustafiz
# message.from.last_name : Sohel
# message.from.username : MustafizS
# message.chat.title : RRU THEFT Detection
# message.chat.type : group
# message.text : KPI3G DHNMK06
# ~~dict~~
# message.from.first_name : Omi
# message.from.username : akomi11
# message.from.language_code : en
# message.chat.title : Cell Outage Update
# message.chat.type : supergroup
# message.new_chat_participant.first_name : Jahid
# message.new_chat_participant.last_name : Hossain
# message.new_chat_participant.username : Jahid181380
# message.new_chat_member.first_name : Jahid
# message.new_chat_member.last_name : Hossain
# message.new_chat_member.username : Jahid181380
# message.new_chat_members[0].first_name : Jahid
# message.new_chat_members[0].last_name : Hossain
# message.new_chat_members[0].username : Jahid181380
# ~~dict~~
# message.from.first_name : Omi
# message.from.username : akomi11
# message.from.language_code : en
# message.chat.title : VIP TOP 5
# message.chat.type : group
# ~~dict~~
# message.from.first_name : Omi
# message.from.username : akomi11
# message.from.language_code : en
# message.chat.title : VIP TOP 5
# message.chat.type : group
# message.text : gisgidgiiu
# ~~dict~~
# message.from.first_name : Ashaduzzaman
# message.from.last_name : Rubel
# message.chat.title : RCA_Site Down
# message.chat.type : group
# message.text : Pls check NKKND18 UP or Down

# %%
print(x)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
