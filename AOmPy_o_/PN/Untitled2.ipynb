# %%
from collections import defaultdict

class pr():
    def __init__(self, value):
        self.hidden_name = value
    def get_name(self):
        print('Getting name:')
        return self.hidden_name
    def set_name(self, value):
        print('Setting name to', value)
        self.hidden_name = value
    name = property(get_name, set_name)

x = pr('omi')

# %%
from collections import defaultdict

class pr():
    def __init__(self, value):
        self.hidden_name = value
    def get_name(self):
        print('Getting name:')
        return self.hidden_name
    def set_name(self, value):
        print('Setting name to', value)
        self.hidden_name = value
    name = property(get_name, set_name)
    
x = pr('qb')

def lastlist(D,kk,vv):
    ky = []
    ND = {}
    ND[kk] = vv
    ky = []
    for k,v in D.items():
        if type(v) is dict:
            ky.append(k)
            lastlist(v)
        else:
            nx = dict(zip(v,ND))
    else:
        if ky is None:
            print(D[k])

class odic():
    def __init__(self):
        self.D = defaultdict(dict)
        self.NK = defaultdict(dict)
    def setd(self, ky, vl):
        if isinstance(vl,list):
            self.D[ky] = vl if not list(self.D) else self.D.get(ky, []) + vl
        else:
            vlx = [vl]
            self.D[ky] = vlx if not list(self.D) else self.D.get(ky, []) + vlx
        #self.NK = dict(zip(self.NK.keys, {ky:vl})) if self.D[ky] != lastlist(self.D[ky]) else dict.fromkeys(self.D[ky],'')
    def pnt(self):
        print(self.NK)
        return self.D
    
z = odic()
z.setd("CAT", ['2G','3G','4G'])
z1 = z.pnt()
lastlist(z1,"sZone",["DHK"])

# %%
from collections import defaultdict

class dc:
    def __init__(self):
        self.dic1 = defaultdict(dict)
    def pnt(self):
        print(self.dic1)
    def addcon(self, col, colval):
        if len(self.dic1)>0:
            ky = list(self.dic1)
        if isinstance(colval,list):
            self.dic1[col] = colval
        elif isinstance(colval,str):
            self.dic1[col] = colval
    def dic_print_loop(self):
        for k, v in self.dic1.items():
            print(k, v)
    def print_ky_vl(self):
        print(list(self.dic1))
        print(list(self.dic1.values()))
    def update_val_by_key_1(self, ky, vl):
        self.dic1[ky].append(vl) #Appending Nested List in value
    def update_val_by_key_2(self, ky, vl):
        self.dic1.setdefault(ky, []).append(vl) #Appending Nested List in value
    def update_val_by_key_3(self, ky, vl):
        self.dic1[ky] = self.dic1.get(ky, []) + vl #Appending List values (not nested)
    def add_ky_vl(self, ky, vl):
        self.dic1[ky] = vl if not list(self.dic1) else self.dic1.get(ky, []) + vl #check and add [best]
    def add_ky_vl_tols(self, ky, vl):
        if isinstance(vl,list):
            self.dic1[ky] = vl if not list(self.dic1) else self.dic1.get(ky, []) + vl #check and add [best]
        else:
            vlx = [vl]
            self.dic1[ky] = vlx if not list(self.dic1) else self.dic1.get(ky, []) + vlx #check and add [best]
    def nested_dic_add(self, k, v):
        if len(self.dic1)>0:
            ln = len(list(self.dic1))
            for i in self.dic1:
                if k in list(self.dic1[i]):
                    self.dic1[i][k] = v if not list(self.dic1[i]) else self.dic1[i].get(k, []) + [v]
            else:
                if isinstance(v, list):
                    self.dic1[ln+1] = {k:v}
                else:
                    v1 = [v]
                    self.dic1[ln+1] = {k:v1}
        else:
            if isinstance(v, list):
                self.dic1[1] = {k:v}
            else:
                v1 = [v]
                self.dic1[1] = {k:v1}
    def gdc(self):
        return self.dic1

y = dc()
y.add_ky_vl_tols("CAT", ['2G','3G','4G'])
D = y.gdc()
dx = xx.getdf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-264a6e7395c0> in <module>
#      57 y.add_ky_vl_tols("CAT", ['2G','3G','4G'])
#      58 D = y.gdc()
# ---> 59 dx = xx.getdf()
#
# NameError: name 'xx' is not defined
